# %% [markdown]
# # Explainable Outcome Prediction - Preprocessing and EDA
#
# - Author: David Steiner
# - December 2021

# %%
# !pip install imblearn
# !pip install pm4py
# !pip install seaborn

# !pip install interpret
# !pip install xgboost
# !pip install catboost

# !pip install keras
# !pip install tensorflow --user
# !pip install keras-tuner

# %%
from prep_custom import get_dataset_settings, xes_converter, add_timestap_features, add_inter_case_features, impute_missing_values
from prep_custom import cut_trace_before_activity, create_trace_bucket,remove_features,remove_events
from prep_custom import split_data_temporal,replace_missing_cols,prepare_ml_train_test, aggregate_data, group_infrequent_features
from prep_custom import define_binary_outcome_label

import pandas as pd
pd.set_option("display.max_columns", 200)
pd.set_option("display.max_rows", 100)

import numpy as np

import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ### Available XES Eventlogs :
#
# - BPI_Challenge_2013_incidents.xes.gz
# - BPI Challenge 2017.xes.gz
# - BPI_Challenge_2019.xes
# - Hospital Billing - Event Log.xes.gz

# %%
# %%time
data = xes_converter('BPI Challenge 2017.xes.gz')
print('Shape:', data.shape)
data.head(5)
# Out:
# parsing log, completed traces ::   0%|          | 0/31509 [00:00<?, ?it/s]
# Shape: (1202267, 19)
# Wall time: 2min 24s
#         Action org:resource            concept:name  EventOrigin  \
# 0      Created       User_1    A_Create Application  Application
# 1  statechange       User_1             A_Submitted  Application
# 2      Created       User_1          W_Handle leads     Workflow
# 3      Deleted       User_1          W_Handle leads     Workflow
# 4      Created       User_1  W_Complete application     Workflow
#
#                  EventID lifecycle:transition  \
# 0  Application_652823628             complete
# 1   ApplState_1582051990             complete
# 2    Workitem_1298499574             schedule
# 3    Workitem_1673366067             withdraw
# 4    Workitem_1493664571             schedule
#
#                     time:timestamp           case:LoanGoal  \
# 0 2016-01-01 09:51:15.304000+00:00  Existing loan takeover
# 1 2016-01-01 09:51:15.352000+00:00  Existing loan takeover
# 2 2016-01-01 09:51:15.774000+00:00  Existing loan takeover
# 3 2016-01-01 09:52:36.392000+00:00  Existing loan takeover
# 4 2016-01-01 09:52:36.403000+00:00  Existing loan takeover
#
#   case:ApplicationType      case:concept:name  case:RequestedAmount  \
# 0           New credit  Application_652823628               20000.0
# 1           New credit  Application_652823628               20000.0
# 2           New credit  Application_652823628               20000.0
# 3           New credit  Application_652823628               20000.0
# 4           New credit  Application_652823628               20000.0
#
#    FirstWithdrawalAmount  NumberOfTerms Accepted  MonthlyCost Selected  \
# 0                    NaN            NaN      NaN          NaN      NaN
# 1                    NaN            NaN      NaN          NaN      NaN
# 2                    NaN            NaN      NaN          NaN      NaN
# 3                    NaN            NaN      NaN          NaN      NaN
# 4                    NaN            NaN      NaN          NaN      NaN
#
#    CreditScore  OfferedAmount OfferID
# 0          NaN            NaN     NaN
# 1          NaN            NaN     NaN
# 2          NaN            NaN     NaN
# 3          NaN            NaN     NaN
# 4          NaN            NaN     NaN

# %%
case_id_col = "case:concept:name"   # Case ID
activity_col = "concept:name"       # Event Name
timestamp_col = 'time:timestamp'    
label_col = 'label'                 # Output Label

#Display shape and one full case
data[data[case_id_col]==data[case_id_col].unique()[0]]
# Out:
#          Action org:resource              concept:name  EventOrigin  \
# 0       Created       User_1      A_Create Application  Application
# 1   statechange       User_1               A_Submitted  Application
# 2       Created       User_1            W_Handle leads     Workflow
# 3       Deleted       User_1            W_Handle leads     Workflow
# 4       Created       User_1    W_Complete application     Workflow
# 5   statechange       User_1                 A_Concept  Application
# 6      Obtained      User_17    W_Complete application     Workflow
# 7      Released      User_17    W_Complete application     Workflow
# 8   statechange      User_52                A_Accepted  Application
# 9       Created      User_52            O_Create Offer        Offer
# 10  statechange      User_52                 O_Created        Offer
# 11  statechange      User_52  O_Sent (mail and online)        Offer
# 12      Deleted      User_52    W_Complete application     Workflow
# 13      Created      User_52       W_Call after offers     Workflow
# 14     Obtained      User_52       W_Call after offers     Workflow
# 15  statechange      User_52                A_Complete  Application
# 16     Released      User_52       W_Call after offers     Workflow
# 17     Obtained      User_11       W_Call after offers     Workflow
# 18     Released      User_11       W_Call after offers     Workflow
# 19      Deleted     User_117       W_Call after offers     Workflow
# 20      Created     User_117    W_Validate application     Workflow
# 21     Obtained     User_117    W_Validate application     Workflow
# 22  statechange     User_117              A_Validating  Application
# 23  statechange     User_117                O_Returned        Offer
# 24     Released     User_117    W_Validate application     Workflow
# 25      Deleted     User_115    W_Validate application     Workflow
# 26      Created     User_115   W_Call incomplete files     Workflow
# 27     Obtained     User_115   W_Call incomplete files     Workflow
# 28  statechange     User_115              A_Incomplete  Application
# 29     Released     User_115   W_Call incomplete files     Workflow
# 30     Obtained       User_2   W_Call incomplete files     Workflow
# 31     Released       User_2   W_Call incomplete files     Workflow
# 32      Deleted     User_117   W_Call incomplete files     Workflow
# 33      Created     User_117    W_Validate application     Workflow
# 34     Obtained     User_117    W_Validate application     Workflow
# 35  statechange     User_117              A_Validating  Application
# 36     Released     User_117    W_Validate application     Workflow
# 37  statechange     User_115                O_Accepted        Offer
# 38  statechange     User_115                 A_Pending  Application
# 39      Deleted     User_115    W_Validate application     Workflow
#
#                   EventID lifecycle:transition  \
# 0   Application_652823628             complete
# 1    ApplState_1582051990             complete
# 2     Workitem_1298499574             schedule
# 3     Workitem_1673366067             withdraw
# 4     Workitem_1493664571             schedule
# 5     ApplState_642383566             complete
# 6     Workitem_1875340971                start
# 7     Workitem_1452291795              suspend
# 8      ApplState_99568828             complete
# 9         Offer_148581083             complete
# 10  OfferState_1514834199             complete
# 11  OfferState_2051164740             complete
# 12    Workitem_1007505836            ate_abort
# 13    Workitem_1087320491             schedule
# 14     Workitem_719909876                start
# 15    ApplState_946455804             complete
# 16    Workitem_1447720177              suspend
# 17    Workitem_1260329040               resume
# 18    Workitem_1152103512              suspend
# 19     Workitem_524990185            ate_abort
# 20     Workitem_781654767             schedule
# 21    Workitem_1641716416                start
# 22    ApplState_752879093             complete
# 23  OfferState_1310330551             complete
# 24     Workitem_823786158              suspend
# 25     Workitem_392297123            ate_abort
# 26     Workitem_835564623             schedule
# 27    Workitem_2031858979                start
# 28    ApplState_390139749             complete
# 29    Workitem_1628953525              suspend
# 30     Workitem_943086771               resume
# 31      Workitem_50564835              suspend
# 32    Workitem_1225999065            ate_abort
# 33     Workitem_801031108             schedule
# 34    Workitem_2071763612                start
# 35   ApplState_1264188685             complete
# 36     Workitem_646578909              suspend
# 37  OfferState_1093322349             complete
# 38   ApplState_1179730815             complete
# 39    Workitem_2067229931            ate_abort
#
#                      time:timestamp           case:LoanGoal  \
# 0  2016-01-01 09:51:15.304000+00:00  Existing loan takeover
# 1  2016-01-01 09:51:15.352000+00:00  Existing loan takeover
# 2  2016-01-01 09:51:15.774000+00:00  Existing loan takeover
# 3  2016-01-01 09:52:36.392000+00:00  Existing loan takeover
# 4  2016-01-01 09:52:36.403000+00:00  Existing loan takeover
# 5  2016-01-01 09:52:36.413000+00:00  Existing loan takeover
# 6  2016-01-02 10:45:22.429000+00:00  Existing loan takeover
# 7  2016-01-02 10:49:28.816000+00:00  Existing loan takeover
# 8  2016-01-02 11:23:04.299000+00:00  Existing loan takeover
# 9  2016-01-02 11:29:03.994000+00:00  Existing loan takeover
# 10 2016-01-02 11:29:05.354000+00:00  Existing loan takeover
# 11 2016-01-02 11:30:28.606000+00:00  Existing loan takeover
# 12 2016-01-02 11:30:28.621000+00:00  Existing loan takeover
# 13 2016-01-02 11:30:28.629000+00:00  Existing loan takeover
# 14 2016-01-02 11:30:28.631000+00:00  Existing loan takeover
# 15 2016-01-02 11:30:28.633000+00:00  Existing loan takeover
# 16 2016-01-02 11:32:41.624000+00:00  Existing loan takeover
# 17 2016-01-06 09:26:44.492000+00:00  Existing loan takeover
# 18 2016-01-06 09:27:08.472000+00:00  Existing loan takeover
# 19 2016-01-13 13:10:55.138000+00:00  Existing loan takeover
# 20 2016-01-13 13:10:55.144000+00:00  Existing loan takeover
# 21 2016-01-13 13:10:55.145000+00:00  Existing loan takeover
# 22 2016-01-13 13:10:55.973000+00:00  Existing loan takeover
# 23 2016-01-13 13:11:03.569000+00:00  Existing loan takeover
# 24 2016-01-13 13:15:39.110000+00:00  Existing loan takeover
# 25 2016-01-14 09:16:20.963000+00:00  Existing loan takeover
# 26 2016-01-14 09:16:20.970000+00:00  Existing loan takeover
# 27 2016-01-14 09:16:20.972000+00:00  Existing loan takeover
# 28 2016-01-14 09:16:20.974000+00:00  Existing loan takeover
# 29 2016-01-14 09:17:46.943000+00:00  Existing loan takeover
# 30 2016-01-14 11:27:28.536000+00:00  Existing loan takeover
# 31 2016-01-14 11:30:19.089000+00:00  Existing loan takeover
# 32 2016-01-14 13:39:51.407000+00:00  Existing loan takeover
# 33 2016-01-14 13:39:51.492000+00:00  Existing loan takeover
# 34 2016-01-14 13:39:51.494000+00:00  Existing loan takeover
# 35 2016-01-14 13:39:51.556000+00:00  Existing loan takeover
# 36 2016-01-14 13:54:49.680000+00:00  Existing loan takeover
# 37 2016-01-14 15:49:11.416000+00:00  Existing loan takeover
# 38 2016-01-14 15:49:11.420000+00:00  Existing loan takeover
# 39 2016-01-14 15:49:11.423000+00:00  Existing loan takeover
#
#    case:ApplicationType      case:concept:name  case:RequestedAmount  \
# 0            New credit  Application_652823628               20000.0
# 1            New credit  Application_652823628               20000.0
# 2            New credit  Application_652823628               20000.0
# 3            New credit  Application_652823628               20000.0
# 4            New credit  Application_652823628               20000.0
# 5            New credit  Application_652823628               20000.0
# 6            New credit  Application_652823628               20000.0
# 7            New credit  Application_652823628               20000.0
# 8            New credit  Application_652823628               20000.0
# 9            New credit  Application_652823628               20000.0
# 10           New credit  Application_652823628               20000.0
# 11           New credit  Application_652823628               20000.0
# 12           New credit  Application_652823628               20000.0
# 13           New credit  Application_652823628               20000.0
# 14           New credit  Application_652823628               20000.0
# 15           New credit  Application_652823628               20000.0
# 16           New credit  Application_652823628               20000.0
# 17           New credit  Application_652823628               20000.0
# 18           New credit  Application_652823628               20000.0
# 19           New credit  Application_652823628               20000.0
# 20           New credit  Application_652823628               20000.0
# 21           New credit  Application_652823628               20000.0
# 22           New credit  Application_652823628               20000.0
# 23           New credit  Application_652823628               20000.0
# 24           New credit  Application_652823628               20000.0
# 25           New credit  Application_652823628               20000.0
# 26           New credit  Application_652823628               20000.0
# 27           New credit  Application_652823628               20000.0
# 28           New credit  Application_652823628               20000.0
# 29           New credit  Application_652823628               20000.0
# 30           New credit  Application_652823628               20000.0
# 31           New credit  Application_652823628               20000.0
# 32           New credit  Application_652823628               20000.0
# 33           New credit  Application_652823628               20000.0
# 34           New credit  Application_652823628               20000.0
# 35           New credit  Application_652823628               20000.0
# 36           New credit  Application_652823628               20000.0
# 37           New credit  Application_652823628               20000.0
# 38           New credit  Application_652823628               20000.0
# 39           New credit  Application_652823628               20000.0
#
#     FirstWithdrawalAmount  NumberOfTerms Accepted  MonthlyCost Selected  \
# 0                     NaN            NaN      NaN          NaN      NaN
# 1                     NaN            NaN      NaN          NaN      NaN
# 2                     NaN            NaN      NaN          NaN      NaN
# 3                     NaN            NaN      NaN          NaN      NaN
# 4                     NaN            NaN      NaN          NaN      NaN
# 5                     NaN            NaN      NaN          NaN      NaN
# 6                     NaN            NaN      NaN          NaN      NaN
# 7                     NaN            NaN      NaN          NaN      NaN
# 8                     NaN            NaN      NaN          NaN      NaN
# 9                 20000.0           44.0     True       498.29     True
# 10                    NaN            NaN      NaN          NaN      NaN
# 11                    NaN            NaN      NaN          NaN      NaN
# 12                    NaN            NaN      NaN          NaN      NaN
# 13                    NaN            NaN      NaN          NaN      NaN
# 14                    NaN            NaN      NaN          NaN      NaN
# 15                    NaN            NaN      NaN          NaN      NaN
# 16                    NaN            NaN      NaN          NaN      NaN
# 17                    NaN            NaN      NaN          NaN      NaN
# 18                    NaN            NaN      NaN          NaN      NaN
# 19                    NaN            NaN      NaN          NaN      NaN
# 20                    NaN            NaN      NaN          NaN      NaN
# 21                    NaN            NaN      NaN          NaN      NaN
# 22                    NaN            NaN      NaN          NaN      NaN
# 23                    NaN            NaN      NaN          NaN      NaN
# 24                    NaN            NaN      NaN          NaN      NaN
# 25                    NaN            NaN      NaN          NaN      NaN
# 26                    NaN            NaN      NaN          NaN      NaN
# 27                    NaN            NaN      NaN          NaN      NaN
# 28                    NaN            NaN      NaN          NaN      NaN
# 29                    NaN            NaN      NaN          NaN      NaN
# 30                    NaN            NaN      NaN          NaN      NaN
# 31                    NaN            NaN      NaN          NaN      NaN
# 32                    NaN            NaN      NaN          NaN      NaN
# 33                    NaN            NaN      NaN          NaN      NaN
# 34                    NaN            NaN      NaN          NaN      NaN
# 35                    NaN            NaN      NaN          NaN      NaN
# 36                    NaN            NaN      NaN          NaN      NaN
# 37                    NaN            NaN      NaN          NaN      NaN
# 38                    NaN            NaN      NaN          NaN      NaN
# 39                    NaN            NaN      NaN          NaN      NaN
#
#     CreditScore  OfferedAmount          OfferID
# 0           NaN            NaN              NaN
# 1           NaN            NaN              NaN
# 2           NaN            NaN              NaN
# 3           NaN            NaN              NaN
# 4           NaN            NaN              NaN
# 5           NaN            NaN              NaN
# 6           NaN            NaN              NaN
# 7           NaN            NaN              NaN
# 8           NaN            NaN              NaN
# 9         979.0        20000.0              NaN
# 10          NaN            NaN  Offer_148581083
# 11          NaN            NaN  Offer_148581083
# 12          NaN            NaN              NaN
# 13          NaN            NaN              NaN
# 14          NaN            NaN              NaN
# 15          NaN            NaN              NaN
# 16          NaN            NaN              NaN
# 17          NaN            NaN              NaN
# 18          NaN            NaN              NaN
# 19          NaN            NaN              NaN
# 20          NaN            NaN              NaN
# 21          NaN            NaN              NaN
# 22          NaN            NaN              NaN
# 23          NaN            NaN  Offer_148581083
# 24          NaN            NaN              NaN
# 25          NaN            NaN              NaN
# 26          NaN            NaN              NaN
# 27          NaN            NaN              NaN
# 28          NaN            NaN              NaN
# 29          NaN            NaN              NaN
# 30          NaN            NaN              NaN
# 31          NaN            NaN              NaN
# 32          NaN            NaN              NaN
# 33          NaN            NaN              NaN
# 34          NaN            NaN              NaN
# 35          NaN            NaN              NaN
# 36          NaN            NaN              NaN
# 37          NaN            NaN  Offer_148581083
# 38          NaN            NaN              NaN
# 39          NaN            NaN              NaN

# %%
# %%time
data = add_timestap_features(data)
data = add_inter_case_features(data)
data = impute_missing_values(data)

#Display shape and one full case
print('Shape:', data.shape)
data[data[case_id_col]==data[case_id_col].unique()[0]]
# Out:
# Extracting timestamp features
# Extracting open cases
# Imputing missing values
# Shape: (1202267, 28)
# Wall time: 1h 32min 1s
#              Action org:resource              concept:name  EventOrigin  \
# 686058      Created       User_1      A_Create Application  Application
# 686059  statechange       User_1               A_Submitted  Application
# 686060      Created       User_1            W_Handle leads     Workflow
# 686061      Deleted       User_1            W_Handle leads     Workflow
# 686062      Created       User_1    W_Complete application     Workflow
# 686063  statechange       User_1                 A_Concept  Application
# 686064     Obtained      User_14    W_Complete application     Workflow
# 686065     Released      User_14    W_Complete application     Workflow
# 686066  statechange       User_5                A_Accepted  Application
# 686067      Created       User_5            O_Create Offer        Offer
# 686068  statechange       User_5                 O_Created        Offer
# 686069  statechange       User_5  O_Sent (mail and online)        Offer
# 686070      Deleted       User_5    W_Complete application     Workflow
# 686071      Created       User_5       W_Call after offers     Workflow
# 686072     Obtained       User_5       W_Call after offers     Workflow
# 686073  statechange       User_5                A_Complete  Application
# 686074     Released       User_5       W_Call after offers     Workflow
# 686075     Obtained      User_18       W_Call after offers     Workflow
# 686076     Released      User_18       W_Call after offers     Workflow
# 686077  statechange       User_1               A_Cancelled  Application
# 686078  statechange       User_1               O_Cancelled        Offer
# 686079      Deleted       User_1       W_Call after offers     Workflow
#
#                        EventID lifecycle:transition  \
# 686058  Application_1000086665             complete
# 686059     ApplState_161925113             complete
# 686060      Workitem_747707399             schedule
# 686061     Workitem_1030261128             withdraw
# 686062     Workitem_1127124826             schedule
# 686063     ApplState_385184570             complete
# 686064      Workitem_518019192                start
# 686065     Workitem_1967765821              suspend
# 686066     ApplState_856156982             complete
# 686067         Offer_410892064             complete
# 686068   OfferState_2071773136             complete
# 686069    OfferState_388269514             complete
# 686070      Workitem_576357058            ate_abort
# 686071     Workitem_1624628008             schedule
# 686072      Workitem_409035147                start
# 686073    ApplState_1103800866             complete
# 686074      Workitem_486281252              suspend
# 686075      Workitem_261413834               resume
# 686076     Workitem_1136881245              suspend
# 686077     ApplState_544389273             complete
# 686078   OfferState_1258287612             complete
# 686079     Workitem_1074507345            ate_abort
#
#                          time:timestamp           case:LoanGoal  \
# 686058 2016-08-03 15:57:21.673000+00:00  Other, see explanation
# 686059 2016-08-03 15:57:21.734000+00:00  Other, see explanation
# 686060 2016-08-03 15:57:21.963000+00:00  Other, see explanation
# 686061 2016-08-03 15:58:28.286000+00:00  Other, see explanation
# 686062 2016-08-03 15:58:28.293000+00:00  Other, see explanation
# 686063 2016-08-03 15:58:28.299000+00:00  Other, see explanation
# 686064 2016-08-04 13:39:29.557000+00:00  Other, see explanation
# 686065 2016-08-04 13:50:12.281000+00:00  Other, see explanation
# 686066 2016-08-05 13:57:07.419000+00:00  Other, see explanation
# 686067 2016-08-05 13:59:57.320000+00:00  Other, see explanation
# 686068 2016-08-05 13:59:58.162000+00:00  Other, see explanation
# 686069 2016-08-05 14:01:23.264000+00:00  Other, see explanation
# 686070 2016-08-05 14:01:23.278000+00:00  Other, see explanation
# 686071 2016-08-05 14:01:23.284000+00:00  Other, see explanation
# 686072 2016-08-05 14:01:23.286000+00:00  Other, see explanation
# 686073 2016-08-05 14:01:23.288000+00:00  Other, see explanation
# 686074 2016-08-05 14:03:01.480000+00:00  Other, see explanation
# 686075 2016-08-09 18:25:01.546000+00:00  Other, see explanation
# 686076 2016-08-09 18:25:32.629000+00:00  Other, see explanation
# 686077 2016-09-05 06:00:36.710000+00:00  Other, see explanation
# 686078 2016-09-05 06:00:36.829000+00:00  Other, see explanation
# 686079 2016-09-05 06:00:36.893000+00:00  Other, see explanation
#
#        case:ApplicationType       case:concept:name  case:RequestedAmount  \
# 686058           New credit  Application_1000086665                5000.0
# 686059           New credit  Application_1000086665                5000.0
# 686060           New credit  Application_1000086665                5000.0
# 686061           New credit  Application_1000086665                5000.0
# 686062           New credit  Application_1000086665                5000.0
# 686063           New credit  Application_1000086665                5000.0
# 686064           New credit  Application_1000086665                5000.0
# 686065           New credit  Application_1000086665                5000.0
# 686066           New credit  Application_1000086665                5000.0
# 686067           New credit  Application_1000086665                5000.0
# 686068           New credit  Application_1000086665                5000.0
# 686069           New credit  Application_1000086665                5000.0
# 686070           New credit  Application_1000086665                5000.0
# 686071           New credit  Application_1000086665                5000.0
# 686072           New credit  Application_1000086665                5000.0
# 686073           New credit  Application_1000086665                5000.0
# 686074           New credit  Application_1000086665                5000.0
# 686075           New credit  Application_1000086665                5000.0
# 686076           New credit  Application_1000086665                5000.0
# 686077           New credit  Application_1000086665                5000.0
# 686078           New credit  Application_1000086665                5000.0
# 686079           New credit  Application_1000086665                5000.0
#
#         FirstWithdrawalAmount  NumberOfTerms Accepted  MonthlyCost Selected  \
# 686058                    0.0            0.0  missing         0.00  missing
# 686059                    0.0            0.0  missing         0.00  missing
# 686060                    0.0            0.0  missing         0.00  missing
# 686061                    0.0            0.0  missing         0.00  missing
# 686062                    0.0            0.0  missing         0.00  missing
# 686063                    0.0            0.0  missing         0.00  missing
# 686064                    0.0            0.0  missing         0.00  missing
# 686065                    0.0            0.0  missing         0.00  missing
# 686066                    0.0            0.0  missing         0.00  missing
# 686067                 5000.0           22.0     True       241.28    False
# 686068                 5000.0           22.0     True       241.28    False
# 686069                 5000.0           22.0     True       241.28    False
# 686070                 5000.0           22.0     True       241.28    False
# 686071                 5000.0           22.0     True       241.28    False
# 686072                 5000.0           22.0     True       241.28    False
# 686073                 5000.0           22.0     True       241.28    False
# 686074                 5000.0           22.0     True       241.28    False
# 686075                 5000.0           22.0     True       241.28    False
# 686076                 5000.0           22.0     True       241.28    False
# 686077                 5000.0           22.0     True       241.28    False
# 686078                 5000.0           22.0     True       241.28    False
# 686079                 5000.0           22.0     True       241.28    False
#
#         CreditScore  OfferedAmount          OfferID  timesincemidnight  month  \
# 686058          0.0            0.0          missing                957      8
# 686059          0.0            0.0          missing                957      8
# 686060          0.0            0.0          missing                957      8
# 686061          0.0            0.0          missing                958      8
# 686062          0.0            0.0          missing                958      8
# 686063          0.0            0.0          missing                958      8
# 686064          0.0            0.0          missing                819      8
# 686065          0.0            0.0          missing                830      8
# 686066          0.0            0.0          missing                837      8
# 686067          0.0         5000.0          missing                839      8
# 686068          0.0         5000.0  Offer_410892064                839      8
# 686069          0.0         5000.0  Offer_410892064                841      8
# 686070          0.0         5000.0  Offer_410892064                841      8
# 686071          0.0         5000.0  Offer_410892064                841      8
# 686072          0.0         5000.0  Offer_410892064                841      8
# 686073          0.0         5000.0  Offer_410892064                841      8
# 686074          0.0         5000.0  Offer_410892064                843      8
# 686075          0.0         5000.0  Offer_410892064               1105      8
# 686076          0.0         5000.0  Offer_410892064               1105      8
# 686077          0.0         5000.0  Offer_410892064                360      9
# 686078          0.0         5000.0  Offer_410892064                360      9
# 686079          0.0         5000.0  Offer_410892064                360      9
#
#         weekday  hour  timesincelastevent  timesincecasestart  event_nr  \
# 686058        2    15            0.000000            0.000000         1
# 686059        2    15            0.001017            0.001017         2
# 686060        2    15            0.003817            0.004833         3
# 686061        2    15            1.105383            1.110217         4
# 686062        2    15            0.000117            1.110333         5
# 686063        2    15            0.000100            1.110433         6
# 686064        3    13         1301.020967         1302.131400         7
# 686065        3    13           10.712067         1312.843467         8
# 686066        4    13         1446.918967         2759.762433         9
# 686067        4    13            2.831683         2762.594117        10
# 686068        4    13            0.014033         2762.608150        11
# 686069        4    14            1.418367         2764.026517        12
# 686070        4    14            0.000233         2764.026750        13
# 686071        4    14            0.000100         2764.026850        14
# 686072        4    14            0.000033         2764.026883        15
# 686073        4    14            0.000033         2764.026917        16
# 686074        4    14            1.636533         2765.663450        17
# 686075        1    18         6022.001100         8787.664550        18
# 686076        1    18            0.518050         8788.182600        19
# 686077        0     6        38135.068017        46923.250617        20
# 686078        0     6            0.001983        46923.252600        21
# 686079        0     6            0.001067        46923.253667        22
#
#         open_cases  label
# 686058        2250  empty
# 686059        2250  empty
# 686060        2250  empty
# 686061        2250  empty
# 686062        2250  empty
# 686063        2250  empty
# 686064        2192  empty
# 686065        2188  empty
# 686066        2191  empty
# 686067        2192  empty
# 686068        2192  empty
# 686069        2191  empty
# 686070        2191  empty
# 686071        2191  empty
# 686072        2191  empty
# 686073        2191  empty
# 686074        2193  empty
# 686075        2306  empty
# 686076        2306  empty
# 686077        2271  empty
# 686078        2271  empty
# 686079        2270  empty

# %%
#Export preprocessed dataset
data.to_csv("BPIC_17.csv", index = False)

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Available Datasets:
#
# - BPIC13
# - BPIC17
# - BPIC19
# - BPICHospital

# %%
data, case_id_col, activity_col, timestamp_col, label_col, resource_col, event_categorical_attributes, event_numeric_attributes, case_categorical_attributes, case_numeric_attributes, static_cols, dynamic_cols, cat_cols = get_dataset_settings('BPIC17')
attributes = [event_categorical_attributes, case_categorical_attributes, event_numeric_attributes, case_numeric_attributes]
# Out:
# Categoric Event Attributes: 8 ['Action', 'org:resource', 'concept:name', 'EventID', 'lifecycle:transition', 'Accepted', 'Selected', 'OfferID']
#
# Numeric Event Attributes: 13 ['FirstWithdrawalAmount', 'NumberOfTerms', 'MonthlyCost', 'CreditScore', 'OfferedAmount', 'timesincemidnight', 'month', 'weekday', 'hour', 'timesincelastevent', 'timesincecasestart', 'event_nr', 'open_cases']
#
# Categoric Case Attributes: 3 ['EventOrigin', 'case:LoanGoal', 'case:ApplicationType']
#
# Numeric Case Attributes: 1 ['case:RequestedAmount']
#
# Dataset Shape (1202267, 28)

# %%
data.aggregate(pd.Series.nunique).sort_values(ascending=False)
# Out:
# EventID                  1202267
# time:timestamp           1202209
# timesincecasestart       1078507
# timesincelastevent        446885
# OfferID                    42996
# case:concept:name          31509
# FirstWithdrawalAmount       5930
# MonthlyCost                 5817
# open_cases                  2707
# timesincemidnight           1400
# case:RequestedAmount         701
# OfferedAmount                664
# CreditScore                  520
# event_nr                     180
# org:resource                 149
# NumberOfTerms                148
# concept:name                  26
# hour                          24
# case:LoanGoal                 14
# month                         12
# lifecycle:transition           7
# weekday                        7
# Action                         5
# Selected                       3
# Accepted                       3
# EventOrigin                    3
# case:ApplicationType           2
# label                          1
# dtype: int64

# %%
print("--- event_numeric_attributes ---")
for col in event_numeric_attributes:
    print(col, '=', len(data[col].unique()), 'unique values', sep=' ')
    print(data[col].describe())
    print()
    
print("--- case_numeric_attributes ---")
for col in case_numeric_attributes:
    print(col, '=', len(data[col].unique()), 'unique values', sep=' ')
    print(data[col].describe())
    print()
# Out:
# --- event_numeric_attributes ---
# FirstWithdrawalAmount = 5930 unique values
# count    1.202267e+06
# mean     6.410647e+03
# std      9.987348e+03
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      1.719000e+03
# 75%      1.000000e+04
# max      7.500000e+04
# Name: FirstWithdrawalAmount, dtype: float64
#
# NumberOfTerms = 148 unique values
# count    1.202267e+06
# mean     6.506787e+01
# std      4.804358e+01
# min      0.000000e+00
# 25%      2.300000e+01
# 50%      6.000000e+01
# 75%      1.200000e+02
# max      1.800000e+02
# Name: NumberOfTerms, dtype: float64
#
# MonthlyCost = 5817 unique values
# count    1.202267e+06
# mean     2.175509e+02
# std      2.036598e+02
# min      0.000000e+00
# 25%      7.000000e+01
# 50%      1.984000e+02
# 75%      3.000700e+02
# max      6.673830e+03
# Name: MonthlyCost, dtype: float64
#
# CreditScore = 520 unique values
# count    1.202267e+06
# mean     3.512002e+02
# std      4.408910e+02
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      8.640000e+02
# max      1.145000e+03
# Name: CreditScore, dtype: float64
#
# OfferedAmount = 664 unique values
# count    1.202267e+06
# mean     1.460996e+04
# std      1.460835e+04
# min      0.000000e+00
# 25%      5.000000e+03
# 50%      1.000000e+04
# 75%      2.000000e+04
# max      7.500000e+04
# Name: OfferedAmount, dtype: float64
#
# timesincemidnight = 1400 unique values
# count    1.202267e+06
# mean     7.200852e+02
# std      2.199310e+02
# min      0.000000e+00
# 25%      5.470000e+02
# 50%      6.990000e+02
# 75%      8.640000e+02
# max      1.439000e+03
# Name: timesincemidnight, dtype: float64
#
# month = 12 unique values
# count    1.202267e+06
# mean     6.763890e+00
# std      3.366534e+00
# min      1.000000e+00
# 25%      4.000000e+00
# 50%      7.000000e+00
# 75%      1.000000e+01
# max      1.200000e+01
# Name: month, dtype: float64
#
# weekday = 7 unique values
# count    1.202267e+06
# mean     2.169753e+00
# std      1.643663e+00
# min      0.000000e+00
# 25%      1.000000e+00
# 50%      2.000000e+00
# 75%      4.000000e+00
# max      6.000000e+00
# Name: weekday, dtype: float64
#
# hour = 24 unique values
# count    1.202267e+06
# mean     1.151794e+01
# std      3.656647e+00
# min      0.000000e+00
# 25%      9.000000e+00
# 50%      1.100000e+01
# 75%      1.400000e+01
# max      2.300000e+01
# Name: hour, dtype: float64
#
# timesincelastevent = 446885 unique values
# count    1.202267e+06
# mean     8.264802e+02
# std      3.882428e+03
# min      0.000000e+00
# 25%      1.166667e-04
# 50%      8.641667e-02
# 75%      4.347358e+00
# max      1.960213e+05
# Name: timesincelastevent, dtype: float64
#
# timesincecasestart = 1078507 unique values
# count    1.202267e+06
# mean     1.301667e+04
# std      1.650955e+04
# min      0.000000e+00
# 25%      5.670105e+02
# 50%      7.548739e+03
# 75%      1.957234e+04
# max      4.119443e+05
# Name: timesincecasestart, dtype: float64
#
# event_nr = 180 unique values
# count    1.202267e+06
# mean     2.323931e+01
# std      1.750326e+01
# min      1.000000e+00
# 25%      1.000000e+01
# 50%      2.000000e+01
# 75%      3.200000e+01
# max      1.800000e+02
# Name: event_nr, dtype: float64
#
# open_cases = 2707 unique values
# count    1.202267e+06
# mean     1.878366e+03
# std      4.217149e+02
# min      0.000000e+00
# 25%      1.586000e+03
# 50%      1.901000e+03
# 75%      2.243000e+03
# max      2.706000e+03
# Name: open_cases, dtype: float64
#
# --- case_numeric_attributes ---
# case:RequestedAmount = 701 unique values
# count    1.202267e+06
# mean     1.675947e+04
# std      1.572320e+04
# min      0.000000e+00
# 25%      6.000000e+03
# 50%      1.400000e+04
# 75%      2.300000e+04
# max      4.500000e+05
# Name: case:RequestedAmount, dtype: float64

# %%
print("--- Dynamic Cat Columns ---")
for col in event_categorical_attributes:
    print(col, '=', len(data[col].unique()), 'unique values', sep=' ')
    print(data[col].unique())
    print()
    
print("--- case_categorical_attributes ---")
for col in case_categorical_attributes:
    print(col, '=', len(data[col].unique()), 'unique values', sep=' ')
    print(data[col].unique())
    print()
# Out:
# --- Dynamic Cat Columns ---
# Action = 5 unique values
# ['Created' 'statechange' 'Deleted' 'Obtained' 'Released']
#
# org:resource = 149 unique values
# ['User_1' 'User_14' 'User_5' 'User_18' 'User_32' 'User_118' 'User_90'
#  'User_71' 'User_16' 'User_132' 'User_91' 'User_119' 'User_58' 'User_121'
#  'User_68' 'User_28' 'User_3' 'User_29' 'User_75' 'User_24' 'User_25'
#  'User_87' 'User_37' 'User_116' 'User_100' 'User_30' 'User_15' 'User_77'
#  'User_53' 'User_133' 'User_67' 'User_123' 'User_7' 'User_23' 'User_126'
#  'User_95' 'User_99' 'User_98' 'User_81' 'User_69' 'User_72' 'User_94'
#  'User_51' 'User_78' 'User_134' 'User_106' 'User_42' 'User_34' 'User_109'
#  'User_48' 'User_120' 'User_102' 'User_43' 'User_115' 'User_13' 'User_27'
#  'User_85' 'User_4' 'User_46' 'User_40' 'User_49' 'User_131' 'User_62'
#  'User_56' 'User_41' 'User_112' 'User_10' 'User_96' 'User_79' 'User_63'
#  'User_80' 'User_83' 'User_52' 'User_60' 'User_39' 'User_122' 'User_2'
#  'User_31' 'User_21' 'User_129' 'User_19' 'User_33' 'User_93' 'User_45'
#  'User_47' 'User_17' 'User_101' 'User_35' 'User_130' 'User_113' 'User_11'
#  'User_128' 'User_44' 'User_125' 'User_36' 'User_107' 'User_104'
#  'User_127' 'User_22' 'User_61' 'User_144' 'User_138' 'User_65' 'User_73'
#  'User_55' 'User_9' 'User_92' 'User_74' 'User_86' 'User_117' 'User_12'
#  'User_114' 'User_70' 'User_26' 'User_54' 'User_76' 'User_84' 'User_38'
#  'User_135' 'User_140' 'User_57' 'User_143' 'User_124' 'User_66' 'User_59'
#  'User_20' 'User_141' 'User_89' 'User_97' 'User_8' 'User_105' 'User_146'
#  'User_137' 'User_64' 'User_136' 'User_108' 'User_88' 'User_139' 'User_50'
#  'User_6' 'User_103' 'User_110' 'User_142' 'User_111' 'User_82' 'User_147'
#  'User_145' 'User_148' 'User_149']
#
# concept:name = 26 unique values
# ['A_Create Application' 'A_Submitted' 'W_Handle leads'
#  'W_Complete application' 'A_Concept' 'A_Accepted' 'O_Create Offer'
#  'O_Created' 'O_Sent (mail and online)' 'W_Call after offers' 'A_Complete'
#  'A_Cancelled' 'O_Cancelled' 'W_Validate application' 'A_Validating'
#  'O_Returned' 'O_Accepted' 'A_Pending' 'W_Call incomplete files'
#  'A_Incomplete' 'A_Denied' 'O_Refused' 'O_Sent (online only)'
#  'W_Assess potential fraud' 'W_Shortened completion '
#  'W_Personal Loan collection']
#
# EventID = 1202267 unique values
# ['Application_1000086665' 'ApplState_161925113' 'Workitem_747707399' ...
#  'OfferState_1927291643' 'ApplState_1253134444' 'Workitem_1302194036']
#
# lifecycle:transition = 7 unique values
# ['complete' 'schedule' 'withdraw' 'start' 'suspend' 'ate_abort' 'resume']
#
# Accepted = 3 unique values
# ['missing' 'True' 'False']
#
# Selected = 3 unique values
# ['missing' 'False' 'True']
#
# OfferID = 42996 unique values
# ['missing' 'Offer_410892064' 'Offer_927137349' ... 'Offer_1512420329'
#  'Offer_148382244' 'Offer_913122697']
#
# --- case_categorical_attributes ---
# EventOrigin = 3 unique values
# ['Application' 'Workflow' 'Offer']
#
# case:LoanGoal = 14 unique values
# ['Other, see explanation' 'Home improvement' 'Car'
#  'Existing loan takeover' 'Not speficied' 'Unknown' 'Caravan / Camper'
#  'Extra spending limit' 'Remaining debt home' 'Motorcycle' 'Boat'
#  'Business goal' 'Tax payments' 'Debt restructuring']
#
# case:ApplicationType = 2 unique values
# ['New credit' 'Limit raise']

# %%
print(data.groupby(activity_col)[case_id_col].count().sort_values(ascending=False))
# Out:
# concept:name
# W_Validate application        209496
# W_Call after offers           191092
# W_Call incomplete files       168529
# W_Complete application        148900
# W_Handle leads                 47264
# O_Create Offer                 42995
# O_Created                      42995
# O_Sent (mail and online)       39707
# A_Validating                   38816
# A_Create Application           31509
# A_Concept                      31509
# A_Accepted                     31509
# A_Complete                     31362
# O_Returned                     23305
# A_Incomplete                   23055
# O_Cancelled                    20898
# A_Submitted                    20423
# O_Accepted                     17228
# A_Pending                      17228
# A_Cancelled                    10431
# O_Refused                       4695
# A_Denied                        3753
# W_Assess potential fraud        3282
# O_Sent (online only)            2026
# W_Shortened completion           238
# W_Personal Loan collection        22
# Name: case:concept:name, dtype: int64

# %%
data.groupby(case_id_col)[activity_col].count().sort_values()
# Out:
# case:concept:name
# Application_1515064385     10
# Application_1829767138     10
# Application_968189026      10
# Application_961957338      10
# Application_523628252      10
#                          ...
# Application_1387439149    154
# Application_1875888758    156
# Application_1359726788    159
# Application_2037628374    180
# Application_1219772874    180
# Name: concept:name, Length: 31509, dtype: int64

# %%
#Display shape and one full case
data[data[case_id_col]==data[case_id_col].unique()[10]]
# Out:
#           Action org:resource              concept:name  EventOrigin  \
# 344      Created       User_1      A_Create Application  Application
# 345  statechange       User_1               A_Submitted  Application
# 346      Created       User_1            W_Handle leads     Workflow
# 347     Obtained       User_5            W_Handle leads     Workflow
# 348      Deleted       User_5            W_Handle leads     Workflow
# 349      Created       User_5    W_Complete application     Workflow
# 350     Obtained       User_5    W_Complete application     Workflow
# 351  statechange       User_5                 A_Concept  Application
# 352     Released       User_5    W_Complete application     Workflow
# 353     Obtained      User_69    W_Complete application     Workflow
# 354     Released      User_69    W_Complete application     Workflow
# 355     Obtained      User_69    W_Complete application     Workflow
# 356     Released      User_69    W_Complete application     Workflow
# 357     Obtained      User_72    W_Complete application     Workflow
# 358     Released      User_72    W_Complete application     Workflow
# 359     Obtained      User_94    W_Complete application     Workflow
# 360     Released      User_94    W_Complete application     Workflow
# 361     Obtained      User_51    W_Complete application     Workflow
# 362  statechange      User_51                A_Accepted  Application
# 363      Created      User_51            O_Create Offer        Offer
# 364  statechange      User_51                 O_Created        Offer
# 365  statechange      User_51  O_Sent (mail and online)        Offer
# 366      Deleted      User_51    W_Complete application     Workflow
# 367      Created      User_51       W_Call after offers     Workflow
# 368     Obtained      User_51       W_Call after offers     Workflow
# 369  statechange      User_51                A_Complete  Application
# 370     Released      User_51       W_Call after offers     Workflow
# 371      Deleted       User_1       W_Call after offers     Workflow
# 372      Created       User_1       W_Call after offers     Workflow
# 373      Deleted     User_123       W_Call after offers     Workflow
# 374      Created     User_123    W_Validate application     Workflow
# 375     Obtained     User_123    W_Validate application     Workflow
# 376  statechange     User_123              A_Validating  Application
# 377  statechange     User_123                O_Returned        Offer
# 378     Released     User_123    W_Validate application     Workflow
# 379      Deleted      User_90    W_Validate application     Workflow
# 380      Created      User_90   W_Call incomplete files     Workflow
# 381     Obtained      User_90   W_Call incomplete files     Workflow
# 382  statechange      User_90              A_Incomplete  Application
# 383     Released      User_90   W_Call incomplete files     Workflow
# 384     Obtained      User_78   W_Call incomplete files     Workflow
# 385     Released      User_78   W_Call incomplete files     Workflow
# 386     Obtained       User_3   W_Call incomplete files     Workflow
# 387     Released       User_3   W_Call incomplete files     Workflow
# 388     Obtained      User_77   W_Call incomplete files     Workflow
# 389     Released      User_77   W_Call incomplete files     Workflow
# 390      Deleted     User_134   W_Call incomplete files     Workflow
# 391      Created     User_134    W_Validate application     Workflow
# 392     Obtained     User_134    W_Validate application     Workflow
# 393  statechange     User_134              A_Validating  Application
# 394     Released     User_134    W_Validate application     Workflow
# 395  statechange     User_106                  A_Denied  Application
# 396  statechange     User_106                 O_Refused        Offer
# 397      Deleted     User_106    W_Validate application     Workflow
#
#                     EventID lifecycle:transition  \
# 344  Application_1000610355             complete
# 345     ApplState_301801710             complete
# 346     Workitem_1519952104             schedule
# 347       Workitem_36541799                start
# 348     Workitem_2031265715             complete
# 349     Workitem_1601853822             schedule
# 350     Workitem_1816633637                start
# 351     ApplState_627387221             complete
# 352      Workitem_965530268              suspend
# 353      Workitem_556328765               resume
# 354      Workitem_863874322              suspend
# 355      Workitem_421638874               resume
# 356      Workitem_737379187              suspend
# 357     Workitem_1192784472               resume
# 358     Workitem_1594372138              suspend
# 359      Workitem_910749749               resume
# 360     Workitem_1689937894              suspend
# 361     Workitem_1990856345               resume
# 362     ApplState_973858399             complete
# 363          Offer_73833420             complete
# 364    OfferState_131177682             complete
# 365    OfferState_690259244             complete
# 366      Workitem_611493543             complete
# 367      Workitem_421806081             schedule
# 368      Workitem_893591884                start
# 369     ApplState_867194552             complete
# 370      Workitem_999991648              suspend
# 371      Workitem_695487366            ate_abort
# 372     Workitem_1129435232             schedule
# 373      Workitem_596943136             withdraw
# 374     Workitem_1250476474             schedule
# 375     Workitem_1027369732                start
# 376     ApplState_949197335             complete
# 377    OfferState_567875974             complete
# 378     Workitem_1238324275              suspend
# 379     Workitem_1190695392            ate_abort
# 380      Workitem_370076272             schedule
# 381      Workitem_687060246                start
# 382      ApplState_50924338             complete
# 383     Workitem_1212740511              suspend
# 384     Workitem_1845325586               resume
# 385     Workitem_1550988887              suspend
# 386      Workitem_848905425               resume
# 387      Workitem_343356854              suspend
# 388      Workitem_903514152               resume
# 389     Workitem_1107392603              suspend
# 390     Workitem_1272681113            ate_abort
# 391      Workitem_198365537             schedule
# 392     Workitem_1971785307                start
# 393    ApplState_1312895350             complete
# 394     Workitem_1834268919              suspend
# 395     ApplState_837719667             complete
# 396   OfferState_1849253845             complete
# 397      Workitem_807442919            ate_abort
#
#                        time:timestamp  case:LoanGoal case:ApplicationType  \
# 344  2016-11-30 08:30:06.392000+00:00  Not speficied           New credit
# 345  2016-11-30 08:30:07.554000+00:00  Not speficied           New credit
# 346  2016-11-30 08:30:07.724000+00:00  Not speficied           New credit
# 347  2016-11-30 12:00:33.801000+00:00  Not speficied           New credit
# 348  2016-11-30 12:00:49.566000+00:00  Not speficied           New credit
# 349  2016-11-30 12:00:49.571000+00:00  Not speficied           New credit
# 350  2016-11-30 12:00:49.572000+00:00  Not speficied           New credit
# 351  2016-11-30 12:00:49.574000+00:00  Not speficied           New credit
# 352  2016-11-30 12:01:19.622000+00:00  Not speficied           New credit
# 353  2016-12-01 08:51:28.530000+00:00  Not speficied           New credit
# 354  2016-12-01 08:51:35.476000+00:00  Not speficied           New credit
# 355  2016-12-01 13:15:39.441000+00:00  Not speficied           New credit
# 356  2016-12-01 13:15:42.323000+00:00  Not speficied           New credit
# 357  2016-12-01 14:36:25.447000+00:00  Not speficied           New credit
# 358  2016-12-01 14:36:31.607000+00:00  Not speficied           New credit
# 359  2016-12-01 14:40:46.411000+00:00  Not speficied           New credit
# 360  2016-12-01 14:40:50.679000+00:00  Not speficied           New credit
# 361  2016-12-01 19:41:34.770000+00:00  Not speficied           New credit
# 362  2016-12-01 19:54:36.513000+00:00  Not speficied           New credit
# 363  2016-12-01 19:57:18.670000+00:00  Not speficied           New credit
# 364  2016-12-01 19:57:19.254000+00:00  Not speficied           New credit
# 365  2016-12-01 19:57:26.541000+00:00  Not speficied           New credit
# 366  2016-12-01 19:57:26.553000+00:00  Not speficied           New credit
# 367  2016-12-01 19:57:26.559000+00:00  Not speficied           New credit
# 368  2016-12-01 19:57:26.561000+00:00  Not speficied           New credit
# 369  2016-12-01 19:57:26.563000+00:00  Not speficied           New credit
# 370  2016-12-01 20:02:50.875000+00:00  Not speficied           New credit
# 371  2016-12-05 06:33:04.047000+00:00  Not speficied           New credit
# 372  2016-12-05 06:33:04.053000+00:00  Not speficied           New credit
# 373  2016-12-20 08:03:59.547000+00:00  Not speficied           New credit
# 374  2016-12-20 08:03:59.554000+00:00  Not speficied           New credit
# 375  2016-12-20 08:03:59.555000+00:00  Not speficied           New credit
# 376  2016-12-20 08:04:00.325000+00:00  Not speficied           New credit
# 377  2016-12-20 08:04:04.592000+00:00  Not speficied           New credit
# 378  2016-12-20 08:06:09.603000+00:00  Not speficied           New credit
# 379  2016-12-20 10:50:37.112000+00:00  Not speficied           New credit
# 380  2016-12-20 10:50:37.117000+00:00  Not speficied           New credit
# 381  2016-12-20 10:50:37.119000+00:00  Not speficied           New credit
# 382  2016-12-20 10:50:37.120000+00:00  Not speficied           New credit
# 383  2016-12-20 10:56:00.340000+00:00  Not speficied           New credit
# 384  2016-12-20 11:41:01.335000+00:00  Not speficied           New credit
# 385  2016-12-20 11:41:17.455000+00:00  Not speficied           New credit
# 386  2016-12-20 11:42:46.982000+00:00  Not speficied           New credit
# 387  2016-12-20 11:43:09.782000+00:00  Not speficied           New credit
# 388  2016-12-20 12:24:17.051000+00:00  Not speficied           New credit
# 389  2016-12-20 13:21:43.145000+00:00  Not speficied           New credit
# 390  2016-12-23 09:45:29.802000+00:00  Not speficied           New credit
# 391  2016-12-23 09:45:29.809000+00:00  Not speficied           New credit
# 392  2016-12-23 09:45:29.811000+00:00  Not speficied           New credit
# 393  2016-12-23 09:45:29.875000+00:00  Not speficied           New credit
# 394  2016-12-23 09:50:38.487000+00:00  Not speficied           New credit
# 395  2016-12-27 08:44:48.425000+00:00  Not speficied           New credit
# 396  2016-12-27 08:44:48.450000+00:00  Not speficied           New credit
# 397  2016-12-27 08:44:48.459000+00:00  Not speficied           New credit
#
#           case:concept:name  case:RequestedAmount  FirstWithdrawalAmount  \
# 344  Application_1000610355               10000.0                    0.0
# 345  Application_1000610355               10000.0                    0.0
# 346  Application_1000610355               10000.0                    0.0
# 347  Application_1000610355               10000.0                    0.0
# 348  Application_1000610355               10000.0                    0.0
# 349  Application_1000610355               10000.0                    0.0
# 350  Application_1000610355               10000.0                    0.0
# 351  Application_1000610355               10000.0                    0.0
# 352  Application_1000610355               10000.0                    0.0
# 353  Application_1000610355               10000.0                    0.0
# 354  Application_1000610355               10000.0                    0.0
# 355  Application_1000610355               10000.0                    0.0
# 356  Application_1000610355               10000.0                    0.0
# 357  Application_1000610355               10000.0                    0.0
# 358  Application_1000610355               10000.0                    0.0
# 359  Application_1000610355               10000.0                    0.0
# 360  Application_1000610355               10000.0                    0.0
# 361  Application_1000610355               10000.0                    0.0
# 362  Application_1000610355               10000.0                    0.0
# 363  Application_1000610355               10000.0                 3500.0
# 364  Application_1000610355               10000.0                 3500.0
# 365  Application_1000610355               10000.0                 3500.0
# 366  Application_1000610355               10000.0                 3500.0
# 367  Application_1000610355               10000.0                 3500.0
# 368  Application_1000610355               10000.0                 3500.0
# 369  Application_1000610355               10000.0                 3500.0
# 370  Application_1000610355               10000.0                 3500.0
# 371  Application_1000610355               10000.0                 3500.0
# 372  Application_1000610355               10000.0                 3500.0
# 373  Application_1000610355               10000.0                 3500.0
# 374  Application_1000610355               10000.0                 3500.0
# 375  Application_1000610355               10000.0                 3500.0
# 376  Application_1000610355               10000.0                 3500.0
# 377  Application_1000610355               10000.0                 3500.0
# 378  Application_1000610355               10000.0                 3500.0
# 379  Application_1000610355               10000.0                 3500.0
# 380  Application_1000610355               10000.0                 3500.0
# 381  Application_1000610355               10000.0                 3500.0
# 382  Application_1000610355               10000.0                 3500.0
# 383  Application_1000610355               10000.0                 3500.0
# 384  Application_1000610355               10000.0                 3500.0
# 385  Application_1000610355               10000.0                 3500.0
# 386  Application_1000610355               10000.0                 3500.0
# 387  Application_1000610355               10000.0                 3500.0
# 388  Application_1000610355               10000.0                 3500.0
# 389  Application_1000610355               10000.0                 3500.0
# 390  Application_1000610355               10000.0                 3500.0
# 391  Application_1000610355               10000.0                 3500.0
# 392  Application_1000610355               10000.0                 3500.0
# 393  Application_1000610355               10000.0                 3500.0
# 394  Application_1000610355               10000.0                 3500.0
# 395  Application_1000610355               10000.0                 3500.0
# 396  Application_1000610355               10000.0                 3500.0
# 397  Application_1000610355               10000.0                 3500.0
#
#      NumberOfTerms Accepted  MonthlyCost Selected  CreditScore  OfferedAmount  \
# 344            0.0  missing          0.0  missing          0.0            0.0
# 345            0.0  missing          0.0  missing          0.0            0.0
# 346            0.0  missing          0.0  missing          0.0            0.0
# 347            0.0  missing          0.0  missing          0.0            0.0
# 348            0.0  missing          0.0  missing          0.0            0.0
# 349            0.0  missing          0.0  missing          0.0            0.0
# 350            0.0  missing          0.0  missing          0.0            0.0
# 351            0.0  missing          0.0  missing          0.0            0.0
# 352            0.0  missing          0.0  missing          0.0            0.0
# 353            0.0  missing          0.0  missing          0.0            0.0
# 354            0.0  missing          0.0  missing          0.0            0.0
# 355            0.0  missing          0.0  missing          0.0            0.0
# 356            0.0  missing          0.0  missing          0.0            0.0
# 357            0.0  missing          0.0  missing          0.0            0.0
# 358            0.0  missing          0.0  missing          0.0            0.0
# 359            0.0  missing          0.0  missing          0.0            0.0
# 360            0.0  missing          0.0  missing          0.0            0.0
# 361            0.0  missing          0.0  missing          0.0            0.0
# 362            0.0  missing          0.0  missing          0.0            0.0
# 363           57.0    False        200.0     True          0.0        10000.0
# 364           57.0    False        200.0     True          0.0        10000.0
# 365           57.0    False        200.0     True          0.0        10000.0
# 366           57.0    False        200.0     True          0.0        10000.0
# 367           57.0    False        200.0     True          0.0        10000.0
# 368           57.0    False        200.0     True          0.0        10000.0
# 369           57.0    False        200.0     True          0.0        10000.0
# 370           57.0    False        200.0     True          0.0        10000.0
# 371           57.0    False        200.0     True          0.0        10000.0
# 372           57.0    False        200.0     True          0.0        10000.0
# 373           57.0    False        200.0     True          0.0        10000.0
# 374           57.0    False        200.0     True          0.0        10000.0
# 375           57.0    False        200.0     True          0.0        10000.0
# 376           57.0    False        200.0     True          0.0        10000.0
# 377           57.0    False        200.0     True          0.0        10000.0
# 378           57.0    False        200.0     True          0.0        10000.0
# 379           57.0    False        200.0     True          0.0        10000.0
# 380           57.0    False        200.0     True          0.0        10000.0
# 381           57.0    False        200.0     True          0.0        10000.0
# 382           57.0    False        200.0     True          0.0        10000.0
# 383           57.0    False        200.0     True          0.0        10000.0
# 384           57.0    False        200.0     True          0.0        10000.0
# 385           57.0    False        200.0     True          0.0        10000.0
# 386           57.0    False        200.0     True          0.0        10000.0
# 387           57.0    False        200.0     True          0.0        10000.0
# 388           57.0    False        200.0     True          0.0        10000.0
# 389           57.0    False        200.0     True          0.0        10000.0
# 390           57.0    False        200.0     True          0.0        10000.0
# 391           57.0    False        200.0     True          0.0        10000.0
# 392           57.0    False        200.0     True          0.0        10000.0
# 393           57.0    False        200.0     True          0.0        10000.0
# 394           57.0    False        200.0     True          0.0        10000.0
# 395           57.0    False        200.0     True          0.0        10000.0
# 396           57.0    False        200.0     True          0.0        10000.0
# 397           57.0    False        200.0     True          0.0        10000.0
#
#             OfferID  timesincemidnight  month  weekday  hour  \
# 344         missing                510     11        2     8
# 345         missing                510     11        2     8
# 346         missing                510     11        2     8
# 347         missing                720     11        2    12
# 348         missing                720     11        2    12
# 349         missing                720     11        2    12
# 350         missing                720     11        2    12
# 351         missing                720     11        2    12
# 352         missing                721     11        2    12
# 353         missing                531     12        3     8
# 354         missing                531     12        3     8
# 355         missing                795     12        3    13
# 356         missing                795     12        3    13
# 357         missing                876     12        3    14
# 358         missing                876     12        3    14
# 359         missing                880     12        3    14
# 360         missing                880     12        3    14
# 361         missing               1181     12        3    19
# 362         missing               1194     12        3    19
# 363         missing               1197     12        3    19
# 364  Offer_73833420               1197     12        3    19
# 365  Offer_73833420               1197     12        3    19
# 366  Offer_73833420               1197     12        3    19
# 367  Offer_73833420               1197     12        3    19
# 368  Offer_73833420               1197     12        3    19
# 369  Offer_73833420               1197     12        3    19
# 370  Offer_73833420               1202     12        3    20
# 371  Offer_73833420                393     12        0     6
# 372  Offer_73833420                393     12        0     6
# 373  Offer_73833420                483     12        1     8
# 374  Offer_73833420                483     12        1     8
# 375  Offer_73833420                483     12        1     8
# 376  Offer_73833420                484     12        1     8
# 377  Offer_73833420                484     12        1     8
# 378  Offer_73833420                486     12        1     8
# 379  Offer_73833420                650     12        1    10
# 380  Offer_73833420                650     12        1    10
# 381  Offer_73833420                650     12        1    10
# 382  Offer_73833420                650     12        1    10
# 383  Offer_73833420                656     12        1    10
# 384  Offer_73833420                701     12        1    11
# 385  Offer_73833420                701     12        1    11
# 386  Offer_73833420                702     12        1    11
# 387  Offer_73833420                703     12        1    11
# 388  Offer_73833420                744     12        1    12
# 389  Offer_73833420                801     12        1    13
# 390  Offer_73833420                585     12        4     9
# 391  Offer_73833420                585     12        4     9
# 392  Offer_73833420                585     12        4     9
# 393  Offer_73833420                585     12        4     9
# 394  Offer_73833420                590     12        4     9
# 395  Offer_73833420                524     12        1     8
# 396  Offer_73833420                524     12        1     8
# 397  Offer_73833420                524     12        1     8
#
#      timesincelastevent  timesincecasestart  event_nr  open_cases  label
# 344            0.000000            0.000000         1        1827  empty
# 345            0.019367            0.019367         2        1827  empty
# 346            0.002833            0.022200         3        1827  empty
# 347          210.434617          210.456817         4        1805  empty
# 348            0.262750          210.719567         5        1805  empty
# 349            0.000083          210.719650         6        1805  empty
# 350            0.000017          210.719667         7        1805  empty
# 351            0.000033          210.719700         8        1805  empty
# 352            0.500800          211.220500         9        1805  empty
# 353         1250.148467         1461.368967        10        1763  empty
# 354            0.115767         1461.484733        11        1763  empty
# 355          264.066083         1725.550817        12        1766  empty
# 356            0.048033         1725.598850        13        1766  empty
# 357           80.718733         1806.317583        14        1768  empty
# 358            0.102667         1806.420250        15        1768  empty
# 359            4.246733         1810.666983        16        1769  empty
# 360            0.071133         1810.738117        17        1769  empty
# 361          300.734850         2111.472967        18        1787  empty
# 362           13.029050         2124.502017        19        1789  empty
# 363            2.702617         2127.204633        20        1789  empty
# 364            0.009733         2127.214367        21        1789  empty
# 365            0.121450         2127.335817        22        1789  empty
# 366            0.000200         2127.336017        23        1789  empty
# 367            0.000100         2127.336117        24        1789  empty
# 368            0.000033         2127.336150        25        1789  empty
# 369            0.000033         2127.336183        26        1789  empty
# 370            5.405200         2132.741383        27        1790  empty
# 371         4950.219533         7082.960917        28        1815  empty
# 372            0.000100         7082.961017        29        1815  empty
# 373        21690.924900        28773.885917        30        1912  empty
# 374            0.000117        28773.886033        31        1912  empty
# 375            0.000017        28773.886050        32        1912  empty
# 376            0.012833        28773.898883        33        1912  empty
# 377            0.071117        28773.970000        34        1912  empty
# 378            2.083517        28776.053517        35        1911  empty
# 379          164.458483        28940.512000        36        1901  empty
# 380            0.000083        28940.512083        37        1901  empty
# 381            0.000033        28940.512117        38        1901  empty
# 382            0.000017        28940.512133        39        1901  empty
# 383            5.387000        28945.899133        40        1900  empty
# 384           45.016583        28990.915717        41        1899  empty
# 385            0.268667        28991.184383        42        1899  empty
# 386            1.492117        28992.676500        43        1899  empty
# 387            0.380000        28993.056500        44        1899  empty
# 388           41.121150        29034.177650        45        1907  empty
# 389           57.434900        29091.612550        46        1902  empty
# 390         4103.777617        33195.390167        47        1522  empty
# 391            0.000117        33195.390283        48        1522  empty
# 392            0.000033        33195.390317        49        1522  empty
# 393            0.001067        33195.391383        50        1522  empty
# 394            5.143533        33200.534917        51        1521  empty
# 395         5694.165633        38894.700550        52        1498  empty
# 396            0.000417        38894.700967        53        1498  empty
# 397            0.000150        38894.701117        54        1497  empty

# %% [markdown]
# ## Dataset Statistics

# %%
def get_dataset_stat(dataset):
    data, case_id_col, activity_col, timestamp_col, label_col, resource_col, event_categorical_attributes, event_numeric_attributes, case_categorical_attributes, case_numeric_attributes, static_cols, dynamic_cols, cat_cols = get_dataset_settings(dataset)
    n_event_categorical_attributes = len(event_categorical_attributes)
    n_event_numeric_attributes = len(event_numeric_attributes) -8
    n_case_categorical_attributes = len(case_categorical_attributes)
    n_case_numeric_attributes = len(case_numeric_attributes)

    n_events = len(data[activity_col].unique())
    tmp = data[[case_id_col, 'event_nr']].groupby([case_id_col]).max()
    n_event_length_max = tmp['event_nr'].max()
    n_event_length_min = tmp['event_nr'].min()
    n_event_length_mean = int(tmp['event_nr'].mean())

    n_cases = len(data[case_id_col].unique())
    
    tmp = data[[case_id_col, 'timesincecasestart']].groupby([case_id_col]).max()
    n_mean_case_duration = round((tmp['timesincecasestart'].mean()/360),1)
    
    dataset_stats = pd.DataFrame()

    dataset_stats = dataset_stats.append(pd.DataFrame({
      'Dataset':[dataset],
      'Cases':[n_cases],
      'Min Case Length': [n_event_length_min], 
      'Max Case Length':[n_event_length_max], 
      'Mean Case Length':[n_event_length_mean], 
      'Mean Duration (hours)':[n_mean_case_duration],
      'Events':[n_events],
      'Cat. Event Attr.':[n_event_categorical_attributes],
      'Num. Event Attr.':[n_event_numeric_attributes],
      'Cat. Case Attr.':[n_case_categorical_attributes],
      'Num. Case Attr. ':[n_case_numeric_attributes]}))
    
    return dataset_stats

# %%
datasets = ['BPIC13', 'BPIC17' ,'BPIC19', 'BPICHospital']

dataset_stats = pd.DataFrame()

for dataset in datasets:
    print(dataset)
    dataset_stat = get_dataset_stat(dataset)
    dataset_stats = dataset_stats.append(dataset_stat)
    
dataset_stats.to_csv("Dataset_Stats.csv", sep=";")
dataset_stats

# %% [markdown]
# ## Business Outcomes Statistics

# %%
outcome_target_list = [
'BPIC17-LoanAccepted',
'BPIC17-PotentialFraud',
'BPIC17-LongRunningCases',
'BPIC13-SupportLevel-1',
'BPIC19-DeletedPO',
'BPICHospital-BillingClosed',
'BPICHospital-CaseReopened',
]

outcome_stats = pd.DataFrame()

for outcome in outcome_target_list:
    print(outcome)
    eventlog = outcome.split('-')[0]

    data, case_id_col, activity_col, timestamp_col, label_col, resource_col, event_categorical_attributes, event_numeric_attributes, case_categorical_attributes, case_numeric_attributes, static_cols, dynamic_cols, cat_cols = get_dataset_settings(eventlog)
    attributes = [event_categorical_attributes, case_categorical_attributes, event_numeric_attributes, case_numeric_attributes]
    data_labeled, drop_events_list, dl_attributes = define_binary_outcome_label(data, attributes, outcome_label=outcome)

    tmp = data_labeled[[case_id_col, label_col]].groupby(case_id_col).max()
    class_1 = tmp[label_col].sum()
    class_0 = len(tmp) - class_1
    class_ratio = round(class_1  / class_0,4)


    outcome_stats = outcome_stats.append(pd.DataFrame({
      'Outcome':[outcome],
      'Class 1':[class_1],
      'Class 0 ': [class_0], 
      'Class Ratio':[class_ratio]
    }))

        
outcome_stats.to_csv("Outcome_Stats.csv", sep=";")

outcome_stats
